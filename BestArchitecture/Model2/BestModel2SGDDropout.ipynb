# %%
#BestModel4
# !python mainConfusionMatrix.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model.. with layer structure : [3, 3, 3]
# The dropout value on linear layer:  0.2
# ==> Learning Rate  0.1
# ==> Optimizer  SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.1
#     lr: 0.1
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0.0005
# )
# ==> Scheduler  <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x154463997df0>
# The number of trainable parameters is:  4359370
# ==> Model training and testing with the layer structure:  [3, 3, 3]
#
# Epoch: 1
#  [================================================================>]  Step: 113ms | Tot: 14s20ms | Train Loss: 1.891 | Train Accuracy: 27.41 313/313
# ...

# %%
import tqdm as notebook_tqdm
# %run PlotConfusionMatrix.py
# Out:
# ==> Confusion Matrix
# ==> Plot variables
